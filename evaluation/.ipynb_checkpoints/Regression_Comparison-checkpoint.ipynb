# %%
from keras.models import load_model
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import r2_score
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the regression models
transformer_model = load_model('../models/transformer_regression_model.h5')
MLP_model = load_model('../models/MLP_regression_model.h5')

# %%
# Load test data
test_df = pd.read_csv('../data/regression_test.csv')

# Extract the columns you want to use as input features
columns = ['BERT_sentiment_score', 'normalised_word_count', 'pub_day', 'pub_hour', 'topic']

x_test = test_df[columns]

y_test = np.array(test_df['n_comments'])

# %%
# Get predicted values
y_pred_transformer = transformer_model.predict(x_test)
y_pred_MLP = MLP_model.predict(x_test)
transformer_r2 = r2_score(y_test, y_pred_transformer)
MLP_r2 = r2_score(y_test, y_pred_MLP)
# Out:
# 78/78 [==============================] - 1s 3ms/step
# 78/78 [==============================] - 0s 1ms/step

# %%
T_mse, T_mae = transformer_model.evaluate(x_test, y_test)
print('Mean squared error:', T_mse)
print('Mean absolute error:', T_mae)
print('R squared: ', transformer_r2)
# Out:
# 78/78 [==============================] - 1s 5ms/step - loss: 210434.1875 - mae: 232.2474
# Mean squared error: 210434.1875
# Mean absolute error: 232.2473602294922
# R squared:  0.265346797786298

# %%
loss, MLP_mse, MLP_mae = MLP_model.evaluate(x_test, y_test)
print('Mean squared error:', MLP_mse)
print('Mean absolute error:', MLP_mae)
print('R squared: ', MLP_r2)
# Out:
# 78/78 [==============================] - 0s 1ms/step - loss: 226819.2656 - mean_squared_error: 226819.2656 - mean_absolute_error: 279.6906
# Mean squared error: 226819.265625
# Mean absolute error: 279.6905822753906
# R squared:  0.20812305501344652

# %%
results_df = pd.DataFrame({"model":["Transformer", "MLP"], 
                    "MSE":[T_mse, MLP_mse], "MAE":[T_mae, MLP_mae], 
                          "R Squared":[transformer_r2, MLP_r2]})
results_df
# Out:
#          model            MSE         MAE  R Squared
# 0  Transformer  210434.187500  232.247360   0.265347
# 1          MLP  226819.265625  279.690582   0.208123

# %%
print(results_df.to_latex(index=False))
# Out:
# \begin{tabular}{lrrr}
# \toprule
#       model &           MSE &        MAE &  R Squared \\
# \midrule
# Transformer & 210434.187500 & 232.247360 &   0.265347 \\
#         MLP & 226819.265625 & 279.690582 &   0.208123 \\
# \bottomrule
# \end{tabular}
# C:\Users\User\AppData\Local\Temp\ipykernel_16692\1821728311.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(results_df.to_latex(index=False))

# %%
# Calculate errors
transformer_errors = y_pred_transformer - y_test
MLP_errors = y_pred_MLP - y_test

# %%
# Scatter plot
plt.scatter(y_test, y_pred_transformer)
plt.title('Transformer: Scatter Plot')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.show()

plt.scatter(y_test, y_pred_MLP)
plt.title('MLP: Scatter Plot')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.show()

# %%
# Residual plots
transformer_residuals = y_test - y_pred_transformer.reshape(-1)
plt.scatter(y_pred_transformer, transformer_residuals)
plt.title('Transformer: Residual Plot')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.show()

MLP_residuals = y_test - y_pred_MLP.reshape(-1)
plt.scatter(y_pred_MLP, MLP_residuals)
plt.title('MLP: Residual Plot')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.show()

# %%
# Distribution plot
sns.displot(transformer_residuals, kde=True)
plt.title('Transformer: Residual Distribution Plot')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.show()

sns.displot(MLP_residuals, kde=True)
plt.title('MLP: Residual Distribution Plot')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.show()

# %%
# Actual vs predicted plots
plt.plot(y_test, label='Actual Values')
plt.plot(y_pred_transformer, label='Predicted Values')
plt.title('Transformer: Actual vs Predicted Plot')
plt.xlabel('Observation')
plt.ylabel('Target Value')
plt.legend()
plt.show()

plt.plot(y_test, label='Actual Values')
plt.plot(y_pred_MLP, label='Predicted Values')
plt.title('MLP: Actual vs Predicted Plot')
plt.xlabel('Observation')
plt.ylabel('Target Value')
plt.legend()
plt.show()
